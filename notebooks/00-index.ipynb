# %% [markdown]
# # 18.032 Interactive notebooks
#
# These interactive notebooks serve as supplementary material for lectures and recitations in 18.032, MIT's class in differential equations. They are designed to help you explore concepts interactively and deepen your understanding of the course material.
#
# New notebooks will be added roughly on a bi-weekly basis throughout the semester.
#
# ## Notebook Index
#
# | Index | Notebook | Date |
# |-------|----------|------|
# | 1 | [Logistic map](./01-logistic-map.ipynb) | 2026-02-04 |
#
# ## Feedback
#
# If you spot errors or have suggestions for improvements, please contact the class UA, Matija Likar, whose email can be found in the course syllabus.
